# %% [markdown]
# <a href="https://colab.research.google.com/github/milfer0516/Proyecto-DataScience-Sector-Salud/blob/main/Depuracion_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

# %%
from google.colab import drive
drive.mount('/content/drive')

# Ruta base definida para que todos usen la misma
# %cd '/content/drive/MyDrive/BootCampEmerTech/Proyecto_Final_Grupo-1/NoteBooks/'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# [Errno 2] No such file or directory: '/content/drive/MyDrive/BootCampEmerTech/Proyecto_Final_Grupo-1/NoteBooks/'
# /content

# %%
import pandas as pd
import numpy as np

# %%
# !git status
# Out:
# On branch main
# Changes to be committed:
#   (use "git restore --staged <file>..." to unstage)
# 	modified:   drive/MyDrive/Colab Notebooks/BootCampEmerTech/Proyecto_Final_Grupo-1/NoteBooks/Depuracion_Data.ipynb
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	drive/MyDrive/Colab Notebooks/BootCampEmerTech/Proyecto_Final_Grupo-1/Data/

# %%
# !git add 'drive/MyDrive/Colab Notebooks/BootCampEmerTech/Proyecto_Final_Grupo-1/NoteBooks/Depuracion_Data.ipynb'

# %%
# !git commit -m "Importo las librerias Pandas, Numpy"
# Out:
# [main 711b45a] Importo las librerias Pandas, Numpy
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite drive/MyDrive/Colab Notebooks/BootCampEmerTech/Proyecto_Final_Grupo-1/NoteBooks/Depuracion_Data.ipynb (98%)

# %%
# !git push -u origin main
# Out:
# Host key verification failed.
# fatal: Could not read from remote repository.
#
# Please make sure you have the correct access rights
# and the repository exists.

# %% [markdown]
# ### Step 1: Check for existing SSH keys
# First, let's check if you already have an SSH key in your Colab environment. If you see `id_rsa` and `id_rsa.pub`, you might already have keys. If not, we'll generate new ones.

# %%
# !ls -al ~/.ssh
# Out:
# ls: cannot access '/root/.ssh': No such file or directory

# %% [markdown]
# ### Step 2: Generate a new SSH key pair (if needed)
# If you didn't see `id_rsa` and `id_rsa.pub` in the previous step, or if you want to generate new ones, run the following command. Replace `"your_email@example.com"` with your GitHub registered email.
#
# When prompted, press `Enter` to accept the default file location and press `Enter` twice to set no passphrase (for simplicity in Colab, though a passphrase is recommended for personal machines).

# %%
# Replace with your GitHub email
# !ssh-keygen -t rsa -b 4096 -C "milfer0516@gmail.com"
# Out:
# Generating public/private rsa key pair.
# Enter file in which to save the key (/root/.ssh/id_rsa):
# Created directory '/root/.ssh'.
# Enter passphrase (empty for no passphrase): #Milfer0516
# Enter same passphrase again: #Milfer0516
# Your identification has been saved in /root/.ssh/id_rsa
# Your public key has been saved in /root/.ssh/id_rsa.pub
# The key fingerprint is:
# SHA256:8Pg532KlKEJcJQlapV6ZiElh0x4TwyT3DwTE67T4wiA milfer0516@gmail.com
# The key's randomart image is:
# +---[RSA 4096]----+
# |  *BX=o.         |
# | o O**oo.        |
# |  +.o+Bo         |
# |   .+..*         |
# |   =.o. S        |
# |E . =  . .  .    |
# |.o o    +. o     |
# |  o o . .o+.     |
# |   . . . ....    |
# +----[SHA256]-----+

# %% [markdown]
# ### Step 3: Display your public SSH key
# Now, display the content of your public key (`id_rsa.pub`). You'll need to copy this entire output.

# %%
# !cat ~/.ssh/id_rsa.pub
# Out:
# ssh-rsa ... milfer0516@gmail.com

# %% [markdown]
# ### Step 4: Add the public key to your GitHub (or other Git host) account
#
# 1.  **Copy the output** from the previous cell (the `ssh-rsa AAAA...` string).
# 2.  Go to your GitHub settings (or the settings of your Git hosting service).
# 3.  Navigate to 'SSH and GPG keys' (or similar section).
# 4.  Click 'New SSH key' or 'Add SSH key'.
# 5.  Give it a descriptive title (e.g., 'Colab Instance').
# 6.  **Paste the copied public key** into the 'Key' field.
# 7.  Click 'Add SSH key'.
#
# _Note: If you are using a different Git hosting service (e.g., GitLab, Bitbucket), the steps will be similar but the exact menu names might vary._

# %% [markdown]
# ### Step 5: Start the SSH agent and add your private key
# To make your SSH key available for Git operations, you need to start the SSH agent and add your private key to it.

# %%
# !bash -c 'eval "$(ssh-agent -s)" && ssh-add ~/.ssh/id_rsa'
# Out:
# Agent pid 32289
# Enter passphrase for /root/.ssh/id_rsa: #Milfer0516
# Identity added: /root/.ssh/id_rsa (milfer0516@gmail.com)

# %% [markdown]
# ### Step 6: Test your SSH connection to GitHub
# After adding the public key to your GitHub account, run this command to verify that the SSH connection is working. You should see a message indicating successful authentication.

# %% [markdown]
# ### Step 6.5: Add GitHub to known_hosts (if host key verification failed)
# If you encountered 'Host key verification failed' in the previous step, it means your system doesn't yet trust GitHub's server. Run the following command to add GitHub's host key to your `known_hosts` file. This tells your SSH client that GitHub is a legitimate server to connect to.

# %%
# !ssh-keyscan github.com >> ~/.ssh/known_hosts
# Out:
# # github.com:22 SSH-2.0-065ec9b
# # github.com:22 SSH-2.0-065ec9b
# # github.com:22 SSH-2.0-065ec9b
# # github.com:22 SSH-2.0-065ec9b
# # github.com:22 SSH-2.0-065ec9b

# %% [markdown]
# ### Step 6.6: Retry Test your SSH connection to GitHub
# Now, retry the SSH connection test. You should see a message indicating successful authentication.

# %%
# !ssh -T git@github.com
# Out:
# git@github.com: Permission denied (publickey).

# %%
# !git remote -v
# Out:
# origin	git@github.com:milfer0516/Proyecto-DataScience-Sector-Salud.git (fetch)
# origin	git@github.com:milfer0516/Proyecto-DataScience-Sector-Salud.git (push)

# %% [markdown]
# If the output shows a URL starting with `https://github.com/` for `origin`, then you need to change it to an SSH URL (e.g., `git@github.com:username/repository.git`).
#
# If it already shows `git@github.com:`, then the issue is more likely with the SSH key setup itself (e.g., key not correctly added to GitHub, or passphrase issue).

# %% [markdown]
# If your remote is HTTPS, you can change it to SSH using this command (replace `your_username` and `your_repository` with your actual GitHub username and repository name):

# %%
# Example: !git remote set-url origin git@github.com:your_username/your_repository.git
# Replace with your actual repository URL:
# !git remote set-url origin git@github.com/milfer0516/BootCampEmerTech_Proyecto_Final_Grupo-1.git

# Please provide your correct repository SSH URL if you know it, otherwise, I can help you find it.
# For now, let's just see the current remote.

# %% [markdown]
# ### Step 7: Retry your `git push`
# If the SSH connection test was successful, you can now retry your `git push` command.

# %%
# Retry the push command
# !git push -u origin main
# Out:
# git@github.com: Permission denied (publickey).
# fatal: Could not read from remote repository.
#
# Please make sure you have the correct access rights
# and the repository exists.

# %% [markdown]
# ### Step 7: Retry your `git push`
# If the SSH connection test was successful, you can now retry your `git push` command. If you still encounter issues, double-check that you've used the correct SSH URL for your remote repository (e.g., `git@github.com:username/repo.git` instead of `https://github.com/username/repo.git`).

# %%
# Retry the push command
# !git push -u origin main
# Out:
# git@github.com: Permission denied (publickey).
# fatal: Could not read from remote repository.
#
# Please make sure you have the correct access rights
# and the repository exists.
